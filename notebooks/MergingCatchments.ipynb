# %% [markdown]
# # Merging Catchments
#
# **Author:** Alexander Michels
#
# This notebook merges together travel-time catchments calculated using parallel SLURM jobs generated from the SPACTS algorithm.
#
# ## Table of Contents
#
# * [Illinois](#il)
# * [Midwest U.S.](#mw)
# * [Conterminous U.S.](#cont)

# %%
import geopandas as gpd
import glob
import json
import pandas as pd
import os
import sys

# %% [markdown]
# <br id="il" />
#
# ## Illinois

# %% [markdown]
# When the SPACTS algorithm spawns parallel jobs, those jobs write out catchments for their own regions. To use these catchments, we want to merge them all together. This can easily be done! First, we grab all of the files using the "glob" package:

# %%
catchment_files = {}
catchment_path = "../data/regions/Illinois/catchments"
dists = ["600","1200", "1800"]
file_pattern = "resource_catchments_{}distance.geojson"

# %% [markdown]
# Use glob to identify all of the files (because we are not going to copy/paste that many files...)

# %%
for dist in dists:
    # fill in the file pattern with the current dist:
    dist_file_pattern = file_pattern.format(dist)
    catchment_files[dist] = glob.glob(os.path.join(catchment_path, f"*/{dist_file_pattern}"))
catchment_files
# Out:
# {'600': ['../data/regions/Illinois/catchments/0007961701/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0100962263/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0005060450/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0003561108/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0012460115/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0001360504/resource_catchments_600distance.geojson',
#   '../data/regions/Illinois/catchments/0001261364/resource_catchments_600distance.geojson'],
#  '1200': ['../data/regions/Illinois/catchments/0007961701/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0100962263/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0005060450/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0003561108/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0012460115/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0001360504/resource_catchments_1200distance.geojson',
#   '../data/regions/Illinois/catchments/0001261364/resource_catchments_1200distance.geojson'],
#  '1800': ['../data/regions/Illinois/catchments/0007961701/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0100962263/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0005060450/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0003561108/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0012460115/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0001360504/resource_catchments_1800distance.geojson',
#   '../data/regions/Illinois/catchments/0001261364/resource_catchments_1800distance.geojson']}

# %% [markdown]
# Load all of the GeoDataFrames:

# %%
unmerged_catchments = {}
for dist in dists:
    unmerged_catchments[dist] = []
    to_load = catchment_files[dist]
    for file_to_load in to_load:
        my_gdf = gpd.read_file(file_to_load)
        # uncomment these to get LOTS of plots:
#         my_gdf.plot()
#         plt.show()
        unmerged_catchments[dist].append(my_gdf)

# %% [markdown]
# We can use the Pandas concat function to glue them all together:

# %%
catchments = []
for dist in dists:
    catchments.append(gpd.GeoDataFrame(pd.concat(unmerged_catchments[dist])))

# %% [markdown]
# Let's check out the result:

# %%
catchments[0].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[1].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[2].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Lastly, save the data into convenient files:

# %%
for i, dist in enumerate([600, 1200, 1800]):
    x = catchments[i].to_crs("EPSG:4326")
    x.to_file(os.path.join("../data/regions/Illinois", f"resource_catchments_{dist}distance.geojson"))
# Out:
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# <br id="mw" />
#
# ## Midwest U.S.

# %% [markdown]
# When the SPACTS algorithm spawns parallel jobs, those jobs write out catchments for their own regions. To use these catchments, we want to merge them all together. This can easily be done! First, we grab all of the files using the "glob" package:

# %%
catchment_files = {}
catchment_path = "../data/regions/Midwest/catchments"
dists = ["600","1200", "1800"]
file_pattern = "resource_catchments_{}distance.geojson"

# %% [markdown]
# Use glob to identify all of the files (because we are not going to copy/paste that many files...)

# %%
for dist in dists:
    # fill in the file pattern with the current dist:
    dist_file_pattern = file_pattern.format(dist)
    catchment_files[dist] = glob.glob(os.path.join(catchment_path, f"*/{dist_file_pattern}"))
catchment_files
# Out:
# {'600': ['../data/regions/Midwest/catchments/0010446750/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0003267526/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0007446526/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0000000094/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0014453188/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0014348118/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0007844857/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001746904/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0006540359/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0017351250/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0005255371/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0011353548/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0016760033/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001261856/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0009960048/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0005555066/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0016045331/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0008560098/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0005047804/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0003749202/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001460123/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0013944622/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0100460548/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0018162286/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0015548183/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0011450801/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0006746151/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0007455720/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001762801/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0003155021/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0004965041/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0005965548/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0010653105/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0157366536/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0003848617/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0011261354/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0004863090/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0000000072/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0003368788/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0006243606/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0012760169/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001360504/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0015654985/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0010560451/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0001261364/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0102640475/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0013843338/resource_catchments_600distance.geojson',
#   '../data/regions/Midwest/catchments/0015354449/resource_catchments_600distance.geojson'],
#  '1200': ['../data/regions/Midwest/catchments/0010446750/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0003267526/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0007446526/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0000000094/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0014453188/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0014348118/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0007844857/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001746904/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0006540359/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0017351250/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0005255371/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0011353548/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0016760033/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001261856/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0009960048/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0005555066/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0016045331/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0008560098/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0005047804/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0003749202/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001460123/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0013944622/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0100460548/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0018162286/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0015548183/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0011450801/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0006746151/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0007455720/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001762801/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0003155021/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0004965041/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0005965548/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0010653105/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0157366536/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0003848617/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0011261354/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0004863090/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0000000072/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0003368788/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0006243606/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0012760169/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001360504/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0015654985/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0010560451/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0001261364/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0102640475/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0013843338/resource_catchments_1200distance.geojson',
#   '../data/regions/Midwest/catchments/0015354449/resource_catchments_1200distance.geojson'],
#  '1800': ['../data/regions/Midwest/catchments/0010446750/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0003267526/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0007446526/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0000000094/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0014453188/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0014348118/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0007844857/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001746904/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0006540359/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0017351250/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0005255371/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0011353548/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0016760033/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001261856/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0009960048/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0005555066/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0016045331/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0008560098/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0005047804/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0003749202/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001460123/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0013944622/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0100460548/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0018162286/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0015548183/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0011450801/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0006746151/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0007455720/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001762801/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0003155021/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0004965041/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0005965548/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0010653105/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0157366536/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0003848617/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0011261354/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0004863090/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0000000072/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0003368788/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0006243606/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0012760169/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001360504/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0015654985/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0010560451/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0001261364/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0102640475/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0013843338/resource_catchments_1800distance.geojson',
#   '../data/regions/Midwest/catchments/0015354449/resource_catchments_1800distance.geojson']}

# %% [markdown]
# Load all of the GeoDataFrames:

# %%
unmerged_catchments = {}
for dist in dists:
    unmerged_catchments[dist] = []
    to_load = catchment_files[dist]
    for file_to_load in to_load:
        my_gdf = gpd.read_file(file_to_load)
        # uncomment these to get LOTS of plots:
#         my_gdf.plot()
#         plt.show()
        unmerged_catchments[dist].append(my_gdf)

# %% [markdown]
# We can use the Pandas concat function to glue them all together:

# %%
catchments = []
for dist in dists:
    catchments.append(gpd.GeoDataFrame(pd.concat(unmerged_catchments[dist])))

# %% [markdown]
# Let's check out the result:

# %%
catchments[0].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[1].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[2].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Lastly, save the data into convenient files:

# %%
for i, dist in enumerate([600, 1200, 1800]):
    x = catchments[i].to_crs("EPSG:4326")
    x.to_file(os.path.join("../data/regions/Midwest", f"resource_catchments_{dist}distance.geojson"))
# Out:
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# <br id="cont" />
#
# ## Conterminous U.S.

# %% [markdown]
# When the SPACTS algorithm spawns parallel jobs, those jobs write out catchments for their own regions. To use these catchments, we want to merge them all together. This can easily be done! First, we grab all of the files using the "glob" package:

# %%
catchment_files = {}
catchment_path = "../data/regions/Conterminous/catchments"
dists = ["600","1200", "1800"]
file_pattern = "resource_catchments_{}distance.geojson"

# %% [markdown]
# Use glob to identify all of the files (because we are not going to copy/paste that many files...)

# %%
for dist in dists:
    # fill in the file pattern with the current dist:
    dist_file_pattern = file_pattern.format(dist)
    catchment_files[dist] = glob.glob(os.path.join(catchment_path, f"*/{dist_file_pattern}"))
catchment_files
# Out:
# {'600': ['../data/regions/Conterminous/catchments/0007446526/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0039595231/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0010685132/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0014408854/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0006540359/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0076777520/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0002061081/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0000000117/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0003435150/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0004765560/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0005021237/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0026691342/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0016760033/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0108408096/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0016045331/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0005784060/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0003906250/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0008390804/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0005587049/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0009436507/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0025133029/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0005998020/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0015548183/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0002328106/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0000401608/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0000822630/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0001913856/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0004965041/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0013474079/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0001422554/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0008130701/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0050378957/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0042079072/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0006728379/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0015319601/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0007327565/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0003566801/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0015654985/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0017470444/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0005189410/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0016738019/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0015037804/resource_catchments_600distance.geojson',
#   '../data/regions/Conterminous/catchments/0082676234/resource_catchments_600distance.geojson'],
#  '1200': ['../data/regions/Conterminous/catchments/0007446526/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0039595231/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0010685132/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0014408854/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0006540359/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0076777520/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0002061081/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0000000117/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0003435150/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0004765560/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0005021237/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0026691342/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0016760033/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0108408096/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0016045331/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0005784060/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0003906250/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0008390804/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0005587049/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0009436507/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0025133029/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0005998020/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0015548183/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0002328106/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0000401608/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0000822630/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0001913856/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0004965041/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0013474079/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0001422554/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0008130701/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0050378957/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0042079072/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0006728379/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0015319601/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0007327565/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0003566801/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0015654985/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0017470444/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0005189410/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0016738019/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0015037804/resource_catchments_1200distance.geojson',
#   '../data/regions/Conterminous/catchments/0082676234/resource_catchments_1200distance.geojson'],
#  '1800': ['../data/regions/Conterminous/catchments/0007446526/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0039595231/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0010685132/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0014408854/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0006540359/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0076777520/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0002061081/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0000000117/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0003435150/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0004765560/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0005021237/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0026691342/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0016760033/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0108408096/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0016045331/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0005784060/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0003906250/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0008390804/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0005587049/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0009436507/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0025133029/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0005998020/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0015548183/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0002328106/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0000401608/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0000822630/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0001913856/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0004965041/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0013474079/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0001422554/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0008130701/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0050378957/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0042079072/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0006728379/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0015319601/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0007327565/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0003566801/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0015654985/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0017470444/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0005189410/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0016738019/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0015037804/resource_catchments_1800distance.geojson',
#   '../data/regions/Conterminous/catchments/0082676234/resource_catchments_1800distance.geojson']}

# %% [markdown]
# Load all of the GeoDataFrames:

# %%
unmerged_catchments = {}
for dist in dists:
    unmerged_catchments[dist] = []
    to_load = catchment_files[dist]
    for file_to_load in to_load:
        my_gdf = gpd.read_file(file_to_load)
        # uncomment these to get LOTS of plots:
#         my_gdf.plot()
#         plt.show()
        unmerged_catchments[dist].append(my_gdf)

# %% [markdown]
# We can use the Pandas concat function to glue them all together:

# %%
catchments = []
for dist in dists:
    catchments.append(gpd.GeoDataFrame(pd.concat(unmerged_catchments[dist])))

# %% [markdown]
# Let's check out the result:

# %%
catchments[0].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[1].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
catchments[2].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Lastly, save the data into convenient files:

# %%
for i, dist in enumerate([600, 1200, 1800]):
    x = catchments[i].to_crs("EPSG:4326")
    x.to_file(os.path.join("../data/regions/Conterminous", f"resource_catchments_{dist}distance.geojson"))
# Out:
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /home/dijkstra/.local/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
